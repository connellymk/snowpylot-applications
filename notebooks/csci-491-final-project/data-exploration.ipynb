# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

notebook_dir = Path.cwd()
notebooks_dir = notebook_dir.parent
repo_root = notebooks_dir.parent

sys.path.insert(0, str(notebooks_dir))

from caaml_utils import parse_caaml_directory

# %%
# Parse all CAAML files in *data_dir* and return a list of Pit objects.
data_dir = repo_root / "snowpits" / "2015_2025"

all_pits = parse_caaml_directory(data_dir)

print(f'Loaded {len(all_pits):,} snow pits')
# Out:
# Loaded 50,278 snow pits

# %% [markdown]
# Your project should encompass at least five distinct categories or topics from the following list:

# %% [markdown]
# 1. Visualizing Amount

# %% [markdown]
# 2. Visualizing Distributions

# %% [markdown]
# 3. Visualizing Proportions

# %% [markdown]
# 4. Visualizing Quantitative Variables

# %% [markdown]
# 5. Dimension Reduction (You may present two plots in this category if employing two different dimension reduction techniques)

# %% [markdown]
# 6. Clustering (You may present two plots in this category if employing two different clustering techniques)

# %% [markdown]
# 7. Visualizing Time Series

# %% [markdown]
# 8. Visualizing Trends

# %% [markdown]
# 9. Visualizing Geospatial Data (Two plots are permissible in this category)
